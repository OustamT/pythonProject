# %% [markdown]
# # Лабораторна робота №5. Списки

# %% [markdown]
# __Мета:__ _освоїти роботу зі списками_

# %% [markdown]
# ## Результат виконання завдань

# %% [markdown]
# ### Завдання 1
#
# Жив-був капелюх. У капелюсі не було кролика, натомість був список із п'яти чисел: `1`, `2`, `3`, `4` та `5`.
#
# Ваше завдання:
#
# * напишіть рядок коду, що пропонує користувачеві замінити число всередині списку цілим числом, введеним користувачем (крок 1)
# * напишіть рядок коду, який видаляє останній елемент зі списку (крок 2)
# * напишіть рядок коду, який друкує довжину існуючого списку (крок 3).
#
# Чи готові до цього випробування?

# %%
hat_list = [1, 2, 3, 4, 5]

center_number = int(input("Введіть бажане число замість початкового середнього: "))

hat_list[2] = center_number
print(hat_list)

del hat_list[-1]
print("\n""результат видалення останнього елемента масиву: ", hat_list)

print("\n""довжина існуючого списку: ", len(hat_list))
# Out:
# Введіть бажане число замість початкового середнього: 7777
# [1, 2, 7777, 4, 5]
#
# результат видалення останнього елемента масиву:  [1, 2, 7777, 4]
#
# довжина існуючого списку:  4

# %% [markdown]
# ### Завдання 2
#
# Написати програму сортування списку у порядку зростання методом бульбашки (додатково: оптимізувати та додати функцію введення масиву).

# %%
array_list = []

for i in range(int(input("Введіть розмір масиву: "))):
    array_list.append(int(input("введіть значення елемента масиву: ")))

print("\n""зовнішній вигляд створеного масиву: ", array_list)

last_value = len(array_list) - 1

while last_value > 0:
    fresh_value = 0
    for i in range(last_value):
        if array_list[i] > array_list[i + 1]:
            array_list[i], array_list[i + 1] = array_list[i + 1], array_list[i]
            fresh_value = i
    last_value = fresh_value

print("\n""відсортований масив: ", array_list)
# Out:
# Введіть розмір масиву: 5
# введіть значення елемента масиву: 8
# введіть значення елемента масиву: 10
# введіть значення елемента масиву: 6
# введіть значення елемента масиву: 4
# введіть значення елемента масиву: 2
#
# зовнішній вигляд створеного масиву:  [8, 10, 6, 4, 2]
#
# відсортований масив:  [2, 4, 6, 8, 10]

# %% [markdown]
# ###  Завдання 3

# %% [markdown]
# Уявіть список - не дуже довгий, не дуже складний, просто звичайний список, що містить деякі цілі числа. Деякі з цих чисел можуть повторюватись, і це ключ до розгадки. Ми не хочемо повторень. Ми хочемо, щоб їх видалили.
#
# Ваше завдання – написати програму, яка видаляє всі дублікати чисел зі списку. Ціль полягає в тому, щоб скласти список, в якому всі числа зустрічаються не більше одного разу.
#
# __Примітка:__ припустимо, що вихідний список жорстко закодований всередині коду - Вам не потрібно вводити його з клавіатури. Звичайно, Ви можете покращити код і додати частину, яка може вести діалог з користувачем і отримувати від неї всі дані.
#
# __Підказка:__ ми рекомендуємо Вам створити новий список як тимчасову робочу область - вам не потрібно оновлювати список in situ.
#
# Ми не надали тестових даних, оскільки було б надто просто. Натомість ви можете використовувати наш скелет.

# %%
fixed_list = []
my_list = [1, 2, 4, 4, 1, 4, 2, 6, 2, 9]

for i in my_list:
    if i not in fixed_list:
        fixed_list.append(i)

print("The list with unique elements only:")
print(my_list)
print("\n""результат після видалення повторів: ""\n", fixed_list)
# Out:
# The list with unique elements only:
# [1, 2, 4, 4, 1, 4, 2, 6, 2, 9]
#
# результат після видалення повторів:
#  [1, 2, 4, 6, 9]

# %% [markdown]
# ### Завдання 4

# %% [markdown]
# Погляньте на шахівницю. Кожне поле містить кілька індексів, які необхідно вказати для доступу до вмісту клітини:
# ![](image/chessboard.jpg)

# %% [markdown]
# Напишіть код, використоувуючи генератори списків, який створює матрицю 8х8 з пустими клітинками (пуста клітинка задається як "_") для задання шахівниці і розставте чотири тури по кутках шахівниці

# %%
chess_field = [['_' for i in range(8)] for j in range(8)]

chess_field[0][0] = "♜"
chess_field[0][7] = "♜"
chess_field[7][0] = "♜"
chess_field[7][7] = "♜"

x = 0
while x < 8:
    print(chess_field[x])
    x += 1
# Out:
# ['♜', '_', '_', '_', '_', '_', '_', '♜']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['_', '_', '_', '_', '_', '_', '_', '_']
# ['♜', '_', '_', '_', '_', '_', '_', '♜']

# %% [markdown]
# ### Контрольні запитання
#
# 1. Який вивод наступного фрагмента?
# ![](image/array_request1.jpg)
# - виведе ['C']
# 2. Який вивод наступного фрагмента?
# ![](image/array_request2.jpg)
# - виведе ['B', 'C']
# 3. Який вивод наступного фрагмента?
# ![](image/array_request3.jpg)
# - виведе []
# 4. Який вивод наступного фрагмента?
# ![](image/array_request4.jpg)
# - виведе ['A', 'B', 'C']
